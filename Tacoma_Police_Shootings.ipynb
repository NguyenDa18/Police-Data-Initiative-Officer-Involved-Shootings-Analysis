# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenDa18/Police-Data-Initiative-Officer-Involved-Shootings-Analysis/blob/master/Tacoma_Police_Shootings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
police_shooting_datasets = {
    'Tacoma_WA': 'https://data.cityoftacoma.org/api/views/4zem-9yq6/rows.csv?accessType=DOWNLOAD',
}

# %%
df = pd.read_csv(police_shooting_datasets['Tacoma_WA'], parse_dates=['Date Occurred'])

# %%
df.columns
# Out:
# Index(['IA Num', 'Inc Num', 'Incident Address', 'District', 'Sector',
#        'Date Received', 'Date Occurred', 'Day of Week', 'Time Occurred',
#        'Hour Occurred', 'Inside/Outside', 'Officer Race', 'Officer Gender',
#        'Officer Age', '# Years Employed ', 'Citizen Race', 'Citizen Gender',
#        'Citizen Age', 'Disposition', 'Action taken'],
#       dtype='object')

# %%
h = df[['Date Occurred', 'Officer Race', 'Officer Gender', 'Citizen Race', 'Citizen Age', 'Action taken']]
h.sort_values(by='Date Occurred')
# Out:
#    Date Occurred Officer Race  ... Citizen Age               Action taken
# 35    2012-08-31        White  ...          29                        NaN
# 21    2012-10-08        White  ...          30  Counseling/Range-Training
# 29    2012-12-22        White  ...          22                        NaN
# 9     2013-02-27        White  ...          35                        NaN
# 13    2013-06-29        White  ...          25                        NaN
# 15    2013-11-25        White  ...          45                        NaN
# 23    2014-02-26        White  ...          23                        NaN
# 19    2015-05-10        White  ...          48                        NaN
# 17    2015-05-22        White  ...          28                        NaN
# 22    2015-08-05        Black  ...          40                        NaN
# 11    2016-01-03        White  ...          26                        NaN
# 7     2016-01-28        White  ...          32                        NaN
# ...

# %%
df['Citizen Race'].value_counts()
# Out:
# Male           17
# White          10
# Black           5
# Asian           1
# Nat Am          1
# Native Amer     1
# Hispanic        1
# Name: Citizen Race, dtype: int64

# %%
df['Officer Race'].value_counts()
# Out:
# White       30
# Asian        3
# Black        2
# Hispanic     1
# Name: Officer Race, dtype: int64
