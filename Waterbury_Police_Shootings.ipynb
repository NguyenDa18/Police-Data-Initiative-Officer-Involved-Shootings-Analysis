# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenDa18/Police-Data-Initiative-Officer-Involved-Shootings-Analysis/blob/master/Waterbury_Police_Shootings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Critique
# - No record of suspect race
# - No record of officer race
# - No record of weapon type

# %%
police_shooting_datasets = {
    'Waterbury_VT': 'https://data.vermont.gov/api/views/du86-kfnp/rows.csv?accessType=DOWNLOAD',
}

# %%
df = pd.read_csv(police_shooting_datasets['Waterbury_VT'], parse_dates=['Date'])

# %%
df.columns
# Out:
# Index(['Date', 'Case ID', 'Trooper', 'Subject', 'Gender', 'Age', 'Injuries',
#        'Town', 'Legal Outcome', 'Summary', 'Count'],
#       dtype='object')

# %%
h = df[['Date', 'Subject', 'Gender', 'Injuries', 'Legal Outcome', 'Summary']]
h.sort_values(by='Date')
# Out:
#          Date  ...                                            Summary
# 25 1977-11-22  ...  Trooper Fagerholm was engaged in a gunfight wi...
# 27 1980-12-22  ...                                       Data Pending
# 28 1983-08-12  ...                                       Data Pending
# 10 1985-09-21  ...  Spackman entered a bar in Brownsville and poin...
# 11 1990-03-17  ...  Sean Allain was shot after leading police on a...
# 29 1991-05-23  ...                                       Data Pending
# 12 1992-10-24  ...  Stephen Walden was intoxicated and reportedly ...
# 0  1996-06-11  ...  Roland Clark drove into the barracks parking l...
# 30 1997-08-19  ...                                       Data Pending
# 1  2000-04-08  ...  Troopers Vargo, Fagerholm, Gemperline and Schm...
# 2  2000-09-23  ...  Wendall Wilcox had shot several rounds at a re...
# 3  2001-09-24  ...  Troopers encountered Borlovan in traffic after...
# ...
