# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenDa18/Police-Data-Initiative-Officer-Involved-Shootings-Analysis/blob/master/Fairfax_Police_Shootings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Critique
# - No record of suspect race
# - No record of officer race
# - No record of weapon type

# %%
police_shooting_datasets = {
  'Fairfax_VA': 'https://opendata.arcgis.com/datasets/f4d29ffadcd34a52bcecefef6f0146da_1.csv',
}

# %%
df = pd.read_csv(police_shooting_datasets['Fairfax_VA'])

# %%
df.columns
# Out:
# Index(['OBJECTID_1', 'FCPDOIS2016_FCPDCaseNumber', 'FCPDOIS2016_Date_',
#        'FCPDOIS2016_Location', 'FCPDOIS2016_MapLocation',
#        'FCPDOIS2016_OfficersInvolved', 'FCPDOIS2016_CommonwealthsAttorn',
#        'FCPDOIS2016_InternalAffairsOutc', 'FCPDOIS2016_SubjectWoundedDecea',
#        'FCPDOIS2016_CaseSummaries', 'FCPDOIS2016_RelatedNewsReleases',
#        'FCPDOIS2016_SEGID'],
#       dtype='object')

# %%
df.head()
# Out:
#    OBJECTID_1  ...  FCPDOIS2016_SEGID
# 0           1  ...             376914
# 1           2  ...            5006764
# 2           3  ...             309842
# 3           4  ...             379999
# 4           5  ...             336895
#
# [5 rows x 12 columns]

# %%
df[['FCPDOIS2016_OfficersInvolved', 'FCPDOIS2016_SubjectWoundedDecea']]
# Out:
#     FCPDOIS2016_OfficersInvolved FCPDOIS2016_SubjectWoundedDecea
# 0                              2                         Wounded
# 1                              1                       No Injury
# 2                              2                         Wounded
# 3                              2                         Wounded
# 4                              1                        Deceased
# 5                              4                        Deceased
# 6                              1                        Deceased
# 7                              2                         Wounded
# 8                              1                         Wounded
# 9                              1                       No Injury
# 10                             1                        Deceased
# 11                             1                        Deceased
# 12                             3                        Deceased
# ...
